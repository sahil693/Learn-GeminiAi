# %% [markdown]
# #Today I'm learning GeminiAi:
# Gemini APi key:
# AIzaSyB5Di4GbRzubzIEBaMr621Lze4g2fEvru0

# %% [markdown]
# # Step 1: Install the package
#
# in order to use Gemini Services we need to install the package

# %%
# !pip install google-generativeai

# %% [markdown]
# # Step 2: Api Configuration
#
# we created an Api, that is used as a connector through python
#
# Gemini AI is google product.
# how can you access with out opening google gemini website
#
# Ans: Api key

# %%
import google.generativeai as genai
api_key="AIzaSyB5Di4GbRzubzIEBaMr621Lze4g2fEvru0"
genai.configure(api_key=api_key)

# %% [markdown]
# #Step 3: Check out the number of models

# %%
for m in genai.list_models():
  print(m.name)

  #Text model: gemini-pro
  #Image model: gemini-pro-vision
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-8b-exp-0827
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %% [markdown]
# #Step 4: Gemini Pro
#
# Text model

# %%
model=genai.GenerativeModel("gemini-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response=model.generate_content("what is the last update of this Google Gemini model")
print(response.text)
# Out:
# As of my knowledge cutoff in April 2023, I do not have information about any Google Gemini model. Therefore, I cannot provide you with the last update information for this model.

# %% [markdown]
# #Image Model
#
# gemini-pro-vision

# %%
model=genai.GenerativeModel("gemini-pro-vision")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image #pillow
img=Image.open("/content/1653895242775.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x480>

# %%
model1=genai.GenerativeModel("gemini-1.5-flash")
prompt="extract all the information from the image"
#prompt1="can you provide caption on the image with humorous and playful manner and make some list of them"
response=model1.generate_content([prompt,img])
print(response.text)
# Out:
# **GATE 2022 Scorecard**
#
# **Graduate Aptitude Test in Engineering (GATE)**
#
# **Name of Candidate:** SHRAVANI ANIL JADHAV
# **Parent's/Guardian's Name:** ANIL MARUTIRAO JADHAV
# **Registration Number:** (Not visible in image)
# **Date of Birth:** (Not visible in image)
# **Examination Paper:** Computer Science and Information Technology (CS)
# **GATE Score:** 692
# **Marks out of 100:** 51
# **All India Rank in this paper:** 632
# **Number of Candidates Appeared in this paper:** 77257
#
# **Qualifying Marks**
# * General: 25.0
# * EWS/OBC (NCL): 22.5
# * SC/ST/PwD: 16.6

# %%
response=model1.generate_content([prompt,img])
print(response.text)

# %% [markdown]
# #Create a Chat

# %%
model=genai.GenerativeModel("gemini-pro")
chat=model.start_chat(history=[])
question="who is PM of India"
response=chat.send_message(question)
print(response.text)
# Out:
# Narendra Modi

# %%
chat.history
# Out:
# [parts {
#    text: "who is PM of India"
#  }
#  role: "user",
#  parts {
#    text: "Narendra Modi"
#  }
#  role: "model"]

# %%
question="He belonging to which party"
response=chat.send_message(question)
print(response.text)
# Out:
# Bharatiya Janata Party (BJP)

# %%
chat.history
# Out:
# [parts {
#    text: "who is PM of India"
#  }
#  role: "user",
#  parts {
#    text: "Narendra Modi"
#  }
#  role: "model",
#  parts {
#    text: "He belonging to which party"
#  }
#  role: "user",
#  parts {
#    text: "Bharatiya Janata Party (BJP)"
#  }
#  role: "model"]

# %%
question="when it is establish?"
response=chat.send_message(question)
print(response.text)
# Out:
# April 6, 1980

# %%
chat.history
# Out:
# [parts {
#    text: "who is PM of India"
#  }
#  role: "user",
#  parts {
#    text: "Narendra Modi"
#  }
#  role: "model",
#  parts {
#    text: "He belonging to which party"
#  }
#  role: "user",
#  parts {
#    text: "Bharatiya Janata Party (BJP)"
#  }
#  role: "model",
#  parts {
#    text: "when it is establish?"
#  }
#  role: "user",
#  parts {
#    text: "April 6, 1980"
#  }
#  role: "model"]

# %%
model=genai.GenerativeModel("gemini-pro")
chat=model.start_chat(history=[])
while True:
  question=input("You: Ask a question ")
  if question=="exit":
     break
  response=chat.send_message(question)
  print("Bot:",response.text)
# Out:
# You: Ask a question Ronaldo full name
# Bot: Cristiano Ronaldo dos Santos Aveiro
# You: Ask a question Cristiano Ronaldo belong to which country
# Bot: Portugal
# You: Ask a question how many kids he have
# Bot: 5
#
# * Cristiano Ronaldo Jr. (born June 17, 2010)
# * Eva Maria Dos Santos (born June 8, 2017)
# * Mateo Ronaldo (born June 8, 2017)
# * Alana Martina dos Santos Aveiro (born November 12, 2017)
# * Bella Esmeralda (born April 18, 2022)
#
# Note that Cristiano Ronaldo Jr.'s mother's identity has never been publicly disclosed. The other four children were born to Ronaldo and his current partner, Georgina Rodríguez.
# You: Ask a question how much Cristiano Ronaldo earn annually
# Bot: According to Forbes, Cristiano Ronaldo earned $120 million in the past year, making him the third-highest paid athlete in the world. Of that $120 million, $70 million came from his salary and bonuses from Manchester United, and $50 million came from endorsements and sponsorships.
#
# ...
